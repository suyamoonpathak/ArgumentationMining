# %%
import os

def compare_folders(txt_folder, xml_folder):
    # Get list of filenames without extensions
    txt_files = {os.path.splitext(file)[0] for file in os.listdir(txt_folder) if file.endswith('.csv')}
    xml_files = {os.path.splitext(file)[0] for file in os.listdir(xml_folder) if file.endswith('.csv')}
    
    # Find matched and unmatched files
    matched_files = txt_files.intersection(xml_files)
    unmatched_files = xml_files.difference(txt_files)

    # Print the results
    print(f"Total matched documents: {len(matched_files)}")
    if matched_files:
        print("Matched documents:")
        for file in matched_files:
            print(file)
    
    print(f"\nTotal unmatched documents: {len(unmatched_files)}")
    if unmatched_files:
        print("Unmatched documents:")
        for file in unmatched_files:
            print(file)

# Example usage:
txt_folder = 'prem_vs_conc_csv_files'  # Replace with the path to your 'original_txt_files' folder
xml_folder = 'argumentative_nonargumentative_FinalCSVs'          # Replace with the path to your 'xml_files' folder

compare_folders(txt_folder, xml_folder)
# Out:
# Total matched documents: 38
# Matched documents:
# R2016_Netherlands Maritime Technology Association formerly Scheepsbouw Nederland v European Commission
# A2011_European Commission (C-106_09 P) and Kingdom of Spain (C-107_09 P) v Government of Gibraltar and United Kingdom of Great Britain and Northern Ireland
# R2021_FVE Holýšov I and Others v Commission
# R2012_European Commission v Électricité de France (EDF)
# R2004_Italian Republic v Commission of the European Communities
# R2004_Daewoo Electronics Manufacturing España SA and Territorio Histórico de Álava - Diputación Foral de Álava v Commission of the European Communities
# A2017_European Commission v Italian Republic_DT
# R2016_Orange v European Commission
# R2016_Hellenic Republic v European Commission
# R2016_European Commission v Hansestadt Lübeck
# A2013_European Commission v Ireland and Others
# R2000_French Republic v Ladbroke Racing Ltd and Commission of the European Communitie
# R2011_European Commission v Kronoply GmbH & Co
# R2015_European Commission v MOL Magyar Olaj- és Gázipari Nyrt
# R2011_France Télécom SA v European Commission
# R2004_Ramondín SA and Ramondín Cápsulas SA (C-186_02 P) and Territorio Histórico de Álava - Diputación Foral de Álava (C-188_02 P) v Commission of the European Communities
# R1997_Tiercé Ladbroke SA v Commission of the European Communities
# R2017_European Commission v Frucona Košice a
# A2017_Ellinikos Chrysos AE Metalleion kai Viomichanias Chrysou v European Commission
# A2009_Commission of the European Communities v Koninklijke FrieslandCampina NV_M
# R2017_Viasat Broadcasting UK Ltd v European Commission
# A2010_NDSHT Nya Destination Stockholm Hotell & Teaterpaket AB v European Commission
# R2013_3F, formerly Specialarbejderforbundet i Danmark (SID) v European Commission
# A2012__BNP Paribas and Banca Nazionale del Lavoro SpA (BNL) v European Commission
# A2009_3F v Commission of the European Communities
# R2021_Prosegur Compañía de Seguridad SA, established in Madrid (Spain) v Commission
# R2021_World Duty Free v. Commission
# A2017_European Commission v TV2_Danmark A_S
# R2010_AceaElectrabel Produzione SpA v European Commission
# A2008_Commission of the European Communities v Salzgitter AG
# A2016_European Commission v Aer Lingus Ltd and Ryanair Designated Activity Company
# A2018_Scuola Elementare Maria Montessori Srl v European Commission
# R2013_Telefónica SA v European Commission
# A2018_Dirk Andres v European Commission
# A2013_Frucona Košice a.s. v European Commission
# A2018_Commission v Spain
# A2016_European_Commission_v_World_Duty_Free
# R2016_DTS Distribuidora de Televisión Digital
#
# Total unmatched documents: 0

# %%
import os

def compare_annotated_csvs_with_xml(csv_folder, xml_folder):
    # Extract base names (without .xml) from xml_files
    xml_files = {os.path.splitext(file)[0] for file in os.listdir(xml_folder) if file.endswith('.xml')}

    # Extract base names from CSVs by stripping '___annotated_judgment.csv'
    csv_files = {
        file.replace('___annotated_judgment', '').replace('.txt', '')
        for file in os.listdir(csv_folder)
        if file.endswith('.txt') and '___annotated_judgment' in file
    }

    # Compare
    matched_files = xml_files.intersection(csv_files)
    unmatched_files = xml_files.difference(csv_files)

    # Output
    print(f"Total matched documents: {len(matched_files)}")
    if matched_files:
        print("Matched documents:")
        for file in sorted(matched_files):
            print(file)

    print("\n" + "-"*40 + "\n")

    print(f"Total unmatched documents: {len(unmatched_files)}")
    if unmatched_files:
        print("Unmatched documents:")
        for file in sorted(unmatched_files):
            print(file)

# Example usage:
csv_folder = 'annotated'  # Replace with actual path
xml_folder = 'xml_files'                                 # Replace with actual path

compare_annotated_csvs_with_xml(csv_folder, xml_folder)
# Out:
# Total matched documents: 39
# Matched documents:
# A2008_Commission of the European Communities v Salzgitter AG
# A2009_3F v Commission of the European Communities
# A2009_Commission of the European Communities v Koninklijke FrieslandCampina NV_M
# A2010_NDSHT Nya Destination Stockholm Hotell & Teaterpaket AB v European Commission
# A2011_European Commission (C-106_09 P) and Kingdom of Spain (C-107_09 P) v Government of Gibraltar and United Kingdom of Great Britain and Northern Ireland
# A2012_BNP Paribas and Banca Nazionale del Lavoro SpA (BNL) v European Commission
# A2013_European Commission v Ireland and Others
# A2013_Frucona Košice a.s. v European Commission
# A2016_European Commission v Aer Lingus Ltd and Ryanair Designated Activity Company
# A2016_European_Commission_v_World_Duty_Free
# A2017_Ellinikos Chrysos AE Metalleion kai Viomichanias Chrysou v European Commission
# A2017_European Commission v Italian Republic_DT
# A2017_European Commission v TV2_Danmark A_S
# A2018_Commission v Spain
# A2018_Dirk Andres v European Commission
# A2018_Scuola Elementare Maria Montessori Srl v European Commission
# R1997_Tiercé Ladbroke SA v Commission of the European Communities
# R2000_French Republic v Ladbroke Racing Ltd and Commission of the European Communitie
# R2004_Daewoo Electronics Manufacturing España SA and Territorio Histórico de Álava - Diputación Foral de Álava v Commission of the European Communities
# R2004_Italian Republic v Commission of the European Communities
# R2004_Ramondín SA and Ramondín Cápsulas SA (C-186_02 P) and Territorio Histórico de Álava - Diputación Foral de Álava (C-188_02 P) v Commission of the European Communities
# R2006_European Commission v Italian Republic
# R2010_AceaElectrabel Produzione SpA v European Commission
# R2011_European Commission v Kronoply GmbH & Co
# R2011_France Télécom SA v European Commission
# R2012_European Commission v Électricité de France (EDF)
# R2013_3F, formerly Specialarbejderforbundet i Danmark (SID) v European Commission
# R2013_Telefónica SA v European Commission
# R2015_European Commission v MOL Magyar Olaj- és Gázipari Nyrt
# R2016_DTS Distribuidora de Televisión Digital
# R2016_European Commission v Hansestadt Lübeck
# R2016_Hellenic Republic v European Commission
# R2016_Netherlands Maritime Technology Association formerly Scheepsbouw Nederland v European Commission
# R2016_Orange v European Commission
# R2017_European Commission v Frucona Košice a
# R2017_Viasat Broadcasting UK Ltd v European Commission
# R2021_FVE Holýšov I and Others v Commission
# R2021_Prosegur Compañía de Seguridad SA, established in Madrid (Spain) v Commission
# R2021_World Duty Free v. Commission
#
# ----------------------------------------
#
# Total unmatched documents: 1
# Unmatched documents:
# R2002_associação dos refinadores de açúcar portugueses

# %%
compare_annotated_csvs_with_xml('prem_vs_conc_csv_files', xml_folder)
# Out:
# Total matched documents: 40
# Matched documents:
# A2008_Commission of the European Communities v Salzgitter AG
# A2009_3F v Commission of the European Communities
# A2009_Commission of the European Communities v Koninklijke FrieslandCampina NV_M
# A2010_NDSHT Nya Destination Stockholm Hotell & Teaterpaket AB v European Commission
# A2011_European Commission (C-106_09 P) and Kingdom of Spain (C-107_09 P) v Government of Gibraltar and United Kingdom of Great Britain and Northern Ireland
# A2012__BNP Paribas and Banca Nazionale del Lavoro SpA (BNL) v European Commission
# A2013_European Commission v Ireland and Others
# A2013_Frucona Košice a.s. v European Commission
# A2016_European Commission v Aer Lingus Ltd and Ryanair Designated Activity Company
# A2016_European_Commission_v_World_Duty_Free
# A2017_Ellinikos Chrysos AE Metalleion kai Viomichanias Chrysou v European Commission
# A2017_European Commission v Italian Republic_DT
# A2017_European Commission v TV2_Danmark A_S
# A2018_Commission v Spain
# A2018_Dirk Andres v European Commission
# A2018_Scuola Elementare Maria Montessori Srl v European Commission
# R1997_Tiercé Ladbroke SA v Commission of the European Communities
# R2000_French Republic v Ladbroke Racing Ltd and Commission of the European Communitie
# R2002_associação dos refinadores de açúcar portugueses
# R2004_Daewoo Electronics Manufacturing España SA and Territorio Histórico de Álava - Diputación Foral de Álava v Commission of the European Communities
# R2004_Italian Republic v Commission of the European Communities
# R2004_Ramondín SA and Ramondín Cápsulas SA (C-186_02 P) and Territorio Histórico de Álava - Diputación Foral de Álava (C-188_02 P) v Commission of the European Communities
# R2006_European Commission v Italian Republic
# R2010_AceaElectrabel Produzione SpA v European Commission
# R2011_European Commission v Kronoply GmbH & Co
# R2011_France Télécom SA v European Commission
# R2012_European Commission v Électricité de France (EDF)
# R2013_3F, formerly Specialarbejderforbundet i Danmark (SID) v European Commission
# R2013_Telefónica SA v European Commission
# R2015_European Commission v MOL Magyar Olaj- és Gázipari Nyrt
# R2016_DTS Distribuidora de Televisión Digital
# R2016_European Commission v Hansestadt Lübeck
# R2016_Hellenic Republic v European Commission
# R2016_Netherlands Maritime Technology Association formerly Scheepsbouw Nederland v European Commission
# R2016_Orange v European Commission
# R2017_European Commission v Frucona Košice a
# R2017_Viasat Broadcasting UK Ltd v European Commission
# R2021_FVE Holýšov I and Others v Commission
# R2021_Prosegur Compañía de Seguridad SA, established in Madrid (Spain) v Commission
# R2021_World Duty Free v. Commission
#
# ----------------------------------------
#
# Total unmatched documents: 0

# %%
import os
import xml.etree.ElementTree as ET

def count_support_and_attack_relations(xml_folder_path):
    results = []

    for filename in os.listdir(xml_folder_path):
        if filename.endswith(".xml"):
            file_path = os.path.join(xml_folder_path, filename)
            try:
                tree = ET.parse(file_path)
                root = tree.getroot()

                support_count = 0
                attack_count = 0

                for elem in root.iter():
                    # Check for SUP attribute
                    if 'SUP' in elem.attrib:
                        supported = elem.attrib['SUP'].split('|')
                        support_count += len(supported)

                    # Check for ATT attribute
                    if 'ATT' in elem.attrib:
                        attacked = elem.attrib['ATT'].split('|')
                        attack_count += len(attacked)

                results.append({
                    'filename': filename,
                    'support_count': support_count,
                    'attack_count': attack_count
                })

            except ET.ParseError as e:
                print(f"Error parsing {filename}: {e}")

    # Print results
    for res in results:
        print(f"File: {res['filename']}")
        print(f"  Support Relations: {res['support_count']}")
        print(f"  Attack Relations:  {res['attack_count']}\n")

# Call the function with the path to your xml_files folder
count_support_and_attack_relations('xml_files')
# Out:
# File: R2011_France Télécom SA v European Commission.xml
#   Support Relations: 77
#   Attack Relations:  0
#
# File: A2018_Commission v Spain.xml
#   Support Relations: 77
#   Attack Relations:  5
#
# File: R2017_European Commission v Frucona Košice a.xml
#   Support Relations: 56
#   Attack Relations:  0
#
# File: A2018_Dirk Andres v European Commission.xml
#   Support Relations: 73
#   Attack Relations:  5
#
# File: A2017_European Commission v Italian Republic_DT.xml
#   Support Relations: 59
#   Attack Relations:  1
#
# File: R2016_DTS Distribuidora de Televisión Digital.xml
#   Support Relations: 84
#   Attack Relations:  6
#
# File: A2018_Scuola Elementare Maria Montessori Srl v European Commission.xml
#   Support Relations: 107
#   Attack Relations:  3
#
# File: R2021_FVE Holýšov I and Others v Commission.xml
#   Support Relations: 34
#   Attack Relations:  8
#
# File: R2016_European Commission v Hansestadt Lübeck.xml
#   Support Relations: 66
#   Attack Relations:  0
#
# File: R2006_European Commission v Italian Republic.xml
#   Support Relations: 38
#   Attack Relations:  1
#
# File: R2004_Ramondín SA and Ramondín Cápsulas SA (C-186_02 P) and Territorio Histórico de Álava - Diputación Foral de Álava (C-188_02 P) v Commission of the European Communities.xml
#   Support Relations: 30
#   Attack Relations:  1
#
# File: R2016_Netherlands Maritime Technology Association formerly Scheepsbouw Nederland v European Commission.xml
#   Support Relations: 58
#   Attack Relations:  10
#
# File: R2016_Orange v European Commission.xml
#   Support Relations: 69
#   Attack Relations:  9
#
# File: A2016_European_Commission_v_World_Duty_Free.xml
#   Support Relations: 73
#   Attack Relations:  1
#
# File: R2021_World Duty Free v. Commission.xml
#   Support Relations: 116
#   Attack Relations:  22
#
# File: A2017_Ellinikos Chrysos AE Metalleion kai Viomichanias Chrysou v European Commission.xml
#   Support Relations: 24
#   Attack Relations:  1
#
# File: R2012_European Commission v Électricité de France (EDF).xml
#   Support Relations: 57
#   Attack Relations:  5
#
# File: R2010_AceaElectrabel Produzione SpA v European Commission.xml
#   Support Relations: 65
#   Attack Relations:  0
#
# File: R2011_European Commission v Kronoply GmbH & Co.xml
#   Support Relations: 48
#   Attack Relations:  0
#
# File: R2013_Telefónica SA v European Commission.xml
#   Support Relations: 33
#   Attack Relations:  1
#
# File: R1997_Tiercé Ladbroke SA v Commission of the European Communities.xml
#   Support Relations: 23
#   Attack Relations:  4
#
# File: A2009_3F v Commission of the European Communities.xml
#   Support Relations: 59
#   Attack Relations:  4
#
# File: R2004_Daewoo Electronics Manufacturing España SA and Territorio Histórico de Álava - Diputación Foral de Álava v Commission of the European Communities.xml
#   Support Relations: 20
#   Attack Relations:  0
#
# File: R2004_Italian Republic v Commission of the European Communities.xml
#   Support Relations: 67
#   Attack Relations:  0
#
# File: R2000_French Republic v Ladbroke Racing Ltd and Commission of the European Communitie.xml
#   Support Relations: 47
#   Attack Relations:  16
#
# File: A2010_NDSHT Nya Destination Stockholm Hotell & Teaterpaket AB v European Commission.xml
#   Support Relations: 39
#   Attack Relations:  1
#
# File: R2002_associação dos refinadores de açúcar portugueses.xml
#   Support Relations: 95
#   Attack Relations:  2
#
# File: A2009_Commission of the European Communities v Koninklijke FrieslandCampina NV_M.xml
#   Support Relations: 48
#   Attack Relations:  0
#
# File: R2015_European Commission v MOL Magyar Olaj- és Gázipari Nyrt.xml
#   Support Relations: 40
#   Attack Relations:  0
#
# File: A2013_Frucona Košice a.s. v European Commission.xml
#   Support Relations: 43
#   Attack Relations:  1
#
# File: A2012_BNP Paribas and Banca Nazionale del Lavoro SpA (BNL) v European Commission.xml
#   Support Relations: 28
#   Attack Relations:  4
#
# File: R2017_Viasat Broadcasting UK Ltd v European Commission.xml
#   Support Relations: 42
#   Attack Relations:  3
#
# File: A2011_European Commission (C-106_09 P) and Kingdom of Spain (C-107_09 P) v Government of Gibraltar and United Kingdom of Great Britain and Northern Ireland.xml
#   Support Relations: 48
#   Attack Relations:  2
#
# File: A2008_Commission of the European Communities v Salzgitter AG.xml
#   Support Relations: 48
#   Attack Relations:  2
#
# File: R2013_3F, formerly Specialarbejderforbundet i Danmark (SID) v European Commission.xml
#   Support Relations: 45
#   Attack Relations:  2
#
# File: R2021_Prosegur Compañía de Seguridad SA, established in Madrid (Spain) v Commission.xml
#   Support Relations: 116
#   Attack Relations:  22
#
# File: A2017_European Commission v TV2_Danmark A_S.xml
#   Support Relations: 30
#   Attack Relations:  1
#
# File: R2016_Hellenic Republic v European Commission.xml
#   Support Relations: 90
#   Attack Relations:  0
#
# File: A2013_European Commission v Ireland and Others.xml
#   Support Relations: 47
#   Attack Relations:  0
#
# File: A2016_European Commission v Aer Lingus Ltd and Ryanair Designated Activity Company.xml
#   Support Relations: 61
#   Attack Relations:  2

# %%
import pandas as pd
CSV_PATH = 'filtered_all.csv'

df = pd.read_csv(CSV_PATH)
file_names = df['file_name'].unique()
assert len(file_names) == 40, f"Expected 40 files, found {len(file_names)}"

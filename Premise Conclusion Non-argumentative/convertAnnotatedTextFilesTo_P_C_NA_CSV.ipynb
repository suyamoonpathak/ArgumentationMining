# %%
import nltk
nltk.download(['punkt', 'wordnet'])

# %% [Cell 2] Import Libraries
import pandas as pd
import re
from nltk.tokenize import PunktSentenceTokenizer
# Out:
# [nltk_data] Downloading package punkt to /home/suyamoon/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/suyamoon/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# %% [Cell 3] Text Reconstruction with Cleaning
def reconstruct_and_clean(annotated_path):
    """Rebuild text with paragraph number removal and position tracking"""
    full_text = []
    fragments = []
    current_pos = 0
    para_pattern = re.compile(r'^\d+(?:\.|\s{2,})\s*')

    with open(annotated_path, 'r', encoding='utf') as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            
            # Split text and annotation
            text_part, _, tag_part = line.partition('||')
            text = para_pattern.sub('', text_part.strip())  # Remove paragraph numbers
            tag = tag_part.strip()
            
            if not text:
                continue

            # Track positions
            start = current_pos
            end = start + len(text)
            full_text.append(text)
            fragments.append({
                'text': text,
                'tag': tag,
                'start': start,
                'end': end
            })
            current_pos = end + 1  # Add space between fragments

    return ' '.join(full_text), fragments

# %%
full_text, fragments = reconstruct_and_clean('annotated/A2009_Commission of the European Communities v Koninklijke FrieslandCampina NV_M___annotated_judgment.txt')
print("RECONSTRUCTED TEXT SAMPLE:")
print(full_text[:300] + "...\n")
print("CLEANED FRAGMENTS EXAMPLE:")
for frag in fragments[:5]:
    print(f"[{frag['start']:04}-{frag['end']:04}] {frag['text'][:50]}... | Tag: {frag['tag']}")
# Out:
# RECONSTRUCTED TEXT SAMPLE:
# JUDGMENT OF 17. 2009 — CASE C-519/07 P JUDGMENT OF THE COURT (Third Chamber) 17 September 2009 * In Case C-519/07 P, APPEAL pursuant to Article 56 of the Statute of the Court of Justice, brought on 21 November 2007, Commission of the European Communities, represented by H. van Vliet and S. Noë, acti...
#
# CLEANED FRAGMENTS EXAMPLE:
# [0000-0015] JUDGMENT OF 17.... | Tag: NA
# [0016-0038] 2009 — CASE C-519/07 P... | Tag:
# [0039-0076] JUDGMENT OF THE COURT (Third Chamber)... | Tag:
# [0077-0096] 17 September 2009 *... | Tag:
# [0097-0116] In Case C-519/07 P,... | Tag:

# %%
def legal_sentence_tokenizer(text):
    """Custom tokenizer for legal text with position tracking"""
    tokenizer = PunktSentenceTokenizer()
    sentences = []
    char_offset = 0
    
    for sent in tokenizer.tokenize(text):
        # Find sentence boundaries in original text
        start = text.find(sent, char_offset)
        end = start + len(sent)
        
        # Legal text adjustments
        if sent.endswith(('v.', 'No.', 'Art.', 'para.', 'pp.')):
            next_char = text[end:end+1]
            if next_char.islower() or next_char.isnumeric():
                continue  # Merge abbreviation with next sentence
        
        sentences.append({
            'text': sent,
            'start': start,
            'end': end
        })
        char_offset = end
    
    return sentences

# %%
sentences = legal_sentence_tokenizer(full_text)
print("\nTOKENIZED SENTENCES:")
print(f"Total sentences: {len(sentences)}")
print("Sample sentences:")
for i, sent in enumerate(sentences[:50]):
    print(f"{i+1}. [{sent['start']:04}-{sent['end']:04}] {sent['text'][:80]}...")
# Out:
# TOKENIZED SENTENCES:
# Total sentences: 188
# Sample sentences:
# 1. [0000-0015] JUDGMENT OF 17....
# 2. [0016-0650] 2009 — CASE C-519/07 P JUDGMENT OF THE COURT (Third Chamber) 17 September 2009 *...
# 3. [0651-0794] I - 8526 COMMISSION / KONINKLIJKE FRIESLANDCAMPINA THE COURT (Third Chamber), co...
# 4. [0795-1616] Cunha Rodrigues, J. Klučka and A. Arabadjiev (Rapporteur), Judges, Advocate Gene...
# 5. [1617-1647] 52; ‘the contested decision’)....
# 6. [1648-1674] I - 8527 1 JUDGMENT OF 17....
# 7. [1675-2078] 2009 — CASE C-519/07 P The national legal framework 2 The Law of 13 December 199...
# 8. [2079-2356] 1996, No 651) inserted Article 15b into the 1969 Law on Corporation Tax (Wet op ...
# 9. [2357-2406] That scheme entered into force on 1 January 1997....
# 10. [2407-3092] 3 The first sentence of Article 15b(1) of the 1969 Law states: ‘In relation to a...
# 11. [3093-3181] The amounts thus set aside can be used for various purposes as provided for by t...
# 12. [3182-3522] Thus, according to Article 15b(5) of that law, in the event of an acquisition of...
# 13. [3523-3834] I - 8528 COMMISSION / KONINKLIJKE FRIESLANDCAMPINA 5 Article 15b(10) of the 1969...
# 14. [3835-3893] The GFA authorisation is granted for a period of 10 years....
# 15. [3894-4247] 6 Following the adoption of the contested decision, Article 1D of the Law of 15 ...
# 16. [4248-4299] 2005 No 468), repealed Article 15b of the 1969 Law....
# 17. [4300-4570] 7 Article 2 of the Law of 15 September 2005 states that, in regard to those taxp...
# 18. [4571-4799] Article 2 also provides that that transitional provision is to apply for a perio...
# 19. [4800-5149] The background to the dispute The facts prior to the contested decision 8 In the...
# 20. [5150-5153] 2)....
# 21. [5154-5314] In that context, the Member States agreed to dismantle progressively specific ta...
# 22. [5315-5480] 2009 — CASE C-519/07 P expressed its intention to examine or re-examine, with re...
# 23. [5481-5637] 9 In the course of that examination, the Commission, by letter of 12 February 19...
# 24. [5638-5715] Those details were provided by that Member State in a letter of 8 March 1999....
# 25. [5716-5855] 10 On 27 December 2000, Koninklijke FrieslandCampina NV (‘KFC’) submitted a requ...
# 26. [5856-6072] 11 By letter of 11 July 2001, the Commission informed the Kingdom of the Netherl...
# 27. [6073-6258] That decision and the request to the interested parties to submit their observat...
# 28. [6259-6262] 6)....
# 29. [6263-6363] 12 On 26 July 2001 the Netherlands tax authority informed KFC that it was initia...
# 30. [6364-6428] Consequently, KFC’s request for GFA authorisation was suspended....
# 31. [6429-6816] 13 By letter of 3 October 2002, the Kingdom of the Netherlands pointed out to th...
# 32. [6817-7235] I - 8530 14 COMMISSION / KONINKLIJKE FRIESLANDCAMPINA On 5 December 2002, the Ne...
# 33. [7236-7742] However, it acknowledged in points 111 and 112 of the grounds for that decision ...
# 34. [7743-7923] Therefore, on the basis of Article 14(1) of Council Regulation (EC) No 659/1999 ...
# 35. [7924-8173] 1), which provides, inter alia, that ‘[the] Commission shall not require recover...
# 36. [8174-8529] 16 Furthermore, in Article 2 of the contested decision, the Commission accepted ...
# 37. [8530-8866] In particular, taking account of the advances made at Community level in the fie...
# 38. [8867-9041] 2009 — CASE C-519/07 P the beneficiaries of that scheme could continue, in view ...
# 39. [9042-9650] The facts subsequent to the contested decision 17 By letter of 11 April 2003, th...
# 40. [9651-9920] 18 In a letter of 7 July 2003 the Commission stated that it was clear from point...
# 41. [9921-10115] It also stated that, if the Netherlands authorities were to grant GFA authorisat...
# 42. [10116-10365] 19 On 21 August 2003, the Netherlands tax authority rejected KFC’s request for G...
# 43. [10366-10874] I - 8532 COMMISSION / KONINKLIJKE FRIESLANDCAMPINA The action before the Court o...
# 44. [10875-10978] 21 As is apparent from paragraph 103 of the judgment under appeal, KFC based its...
# 45. [10979-11274] The first of those contained two limbs, claiming, first, breach of the principle...
# 46. [11275-11405] The second plea alleged breach of the principle of equal treatment, and the thir...
# 47. [11406-11573] 22 The Commission, primarily, submitted two pleas of inadmissibility and, in the...
# 48. [11574-11643] 23 The Court of First Instance rejected the pleas of inadmissibility....
# 49. [11644-12089] In the first place, as regards the absolute bar owing to the lack of interest in...
# 50. [12090-12373] 24 As regards the absolute bar owing to the lack of standing, the Court of First...

# %%
def map_annotations(sentences, fragments):
    dataset = []
    
    for sent in sentences:
        class_label = "NA"  # Default to non-argumentative
        sent_start = sent['start']
        sent_end = sent['end']
        
        for frag in fragments:
            # Skip empty tags and NA fragments
            if frag['tag'] in ('', 'NA'):
                continue
                
            # Extract argument type (P/C) from tag
            tag_type = frag['tag'].split('_')[0]
            if tag_type not in ('P', 'C'):
                continue

            # Calculate overlap
            overlap_start = max(sent_start, frag['start'])
            overlap_end = min(sent_end, frag['end'])
            
            if overlap_start < overlap_end:
                overlap_ratio = (overlap_end - overlap_start) / (frag['end'] - frag['start'])
                if overlap_ratio > 0.6:
                    class_label = tag_type  # Set to P/C
                    break  # First qualifying fragment determines class
        
        dataset.append({
            'text': sent['text'].strip(),
            'class': class_label
        })
    
    return pd.DataFrame(dataset)

# %%
df = map_annotations(sentences, fragments)

# %%
print("\nDATASET PREVIEW:")
print(f"Class Distribution:\n{df['class'].value_counts()}\n")
print("Sample Argumentative Sentences:")
print(df[df['class'] == 1].head(3))
print("\nSample Non-Argumentative Sentences:")
print(df[df['class'] == 0].head(3))
# Out:
# DATASET PREVIEW:
# Class Distribution:
# class
# NA    135
# P      49
# C       4
# Name: count, dtype: int64
#
# Sample Argumentative Sentences:
# Empty DataFrame
# Columns: [text, class]
# Index: []
#
# Sample Non-Argumentative Sentences:
# Empty DataFrame
# Columns: [text, class]
# Index: []

# %%
def final_clean(text):
    """Remove residual noise while preserving legal references"""
    # Remove standalone numbers and bullet points
    text = re.sub(r'^\d+\.?\s*', '', text)
    # Normalize quotation marks
    text = re.sub(r'[”“â€˜â€™]', "'", text)
    # Fix encoding artifacts
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# Apply final cleaning
df['cleaned_text'] = df['text'].apply(final_clean)
df = df[df['cleaned_text'].ne('')]

# Export to CSV
output_path = 'cleaned_legal_dataset.csv'
df[['text', 'class']].to_csv(output_path, index=False) 

print("\nFINAL DATASET SAMPLE:")
print(f"Class Distribution:\n{df['class'].value_counts()}\n")
print("Sample Premises:")
print(df[df['class'] == 'P'].head(3))
print("\nSample Conclusions:")
print(df[df['class'] == 'C'].head(3))
# Out:
# FINAL DATASET SAMPLE:
# Class Distribution:
# class
# NA    135
# P      49
# C       4
# Name: count, dtype: int64
#
# Sample Premises:
#                                                  text class  \
# 89  Findings of the Court the 11 July 2001 47 Unde...     P
# 91  2009 — CASE C-519/07 P 48 In relation to the f...     P
# 92  49 In the present case, as the Court of First ...     P
#
#                                          cleaned_text
# 89  Findings of the Court the 11 July 2001 47 Unde...
# 91  — CASE C-519/07 P 48 In relation to the first ...
# 92  In the present case, as the Court of First Ins...
#
# Sample Conclusions:
#                                                   text class  \
# 109  61 It follows that the second plea must be rej...     C
# 123  69 It follows that the first plea must be reje...     C
# 166  96 It follows that the second limb of the four...     C
#
#                                           cleaned_text
# 109  It follows that the second plea must be reject...
# 123   It follows that the first plea must be rejected.
# 166  It follows that the second limb of the fourth ...

# %%
import os

def process_directory(input_dir, output_dir):
    os.makedirs(output_dir, exist_ok=True)
    
    for filename in os.listdir(input_dir):
        if filename.endswith('_annotated_judgment.txt'):
            input_path = os.path.join(input_dir, filename)
            full_text, fragments = reconstruct_and_clean(input_path)
            sentences = legal_sentence_tokenizer(full_text)
            df = map_annotations(sentences, fragments)
            output_path = os.path.join(output_dir, filename.replace('.txt', '.csv'))
            df.to_csv(output_path, index=False)

# Example usage:

# %%
process_directory('annotated_by_shivani', 'P_C_NA csv')

# %%
process_directory('annotated', 'P_C_NA csv')

# %%
# %% [Cell 1] Add Enhanced Cleaning Functions
import pandas as pd
import re

def remove_leading_numbers(text):
    """Remove 1-3 digit numbers at start of text with trailing period/space"""
    return re.sub(r'^\d{1,3}\.*\s*', '', text).strip()

def filter_short_phrases(df):
    """Remove rows with fewer than 3 words"""
    return df[df['text'].apply(lambda x: len(str(x).split()) >= 3)]

# %% [Cell 2] Enhanced Processing Pipeline
def enhanced_processing(input_csv, output_csv):
    # Load cleaned dataset
    df = pd.read_csv(input_csv)
    
    print("Before enhanced cleaning:")
    print(f"Total rows: {len(df)}")
    
    # Remove leading numbers
    df['text'] = df['text'].apply(remove_leading_numbers)
    
    # Filter short phrases
    initial_count = len(df)
    df = filter_short_phrases(df)
    
    # Preserve NA labels explicitly
    df['class'] = df['class'].fillna('NA')  # New line to fix missing labels
    
    print("\nAfter enhanced cleaning:")
    print(f"Removed {initial_count - len(df)} rows")
    print(f"Remaining rows: {len(df)}")
    
    # Save final dataset
    df.to_csv(output_csv, index=False)
    return df

# %%
def process_directory(input_dir, output_dir):
    # Create output directory if not exists
    os.makedirs(output_dir, exist_ok=True)
    
    # Verify input directory exists
    if not os.path.exists(input_dir):
        raise FileNotFoundError(f"Input directory '{input_dir}' not found")
    
    # Get list of CSV files
    csv_files = [f for f in os.listdir(input_dir) if f.endswith('.csv')]
    
    if not csv_files:
        print(f"No CSV files found in {input_dir}")
        return
    
    # Process each file
    for csv_file in csv_files:
        input_path = os.path.join(input_dir, csv_file)
        output_path = os.path.join(output_dir, csv_file)
        
        print(f"Processing {csv_file}...")
        final_df = enhanced_processing(input_path, output_path)
        
        if final_df is not None:
            print(f"Processed {len(final_df)} rows -> {output_path}")

# %%
# Run the processing
process_directory(
    'P_C_NA csv',
    'P_C_NA csv final combined'
)
# Out:
# Processing L_A2016_European_Commission_v_World_Duty_Free _annotated_judgment.csv...
# Before enhanced cleaning:
# Total rows: 188
#
# After enhanced cleaning:
# Removed 1 rows
# Remaining rows: 187
# Processed 187 rows -> P_C_NA csv final combined/L_A2016_European_Commission_v_World_Duty_Free _annotated_judgment.csv
# Processing R2016_Orange v European Commission___annotated_judgment.csv...
# Before enhanced cleaning:
# Total rows: 147
#
# After enhanced cleaning:
# Removed 1 rows
# Remaining rows: 146
# Processed 146 rows -> P_C_NA csv final combined/R2016_Orange v European Commission___annotated_judgment.csv
# Processing A2018_Dirk Andres v European Commission___annotated_judgment.csv...
# Before enhanced cleaning:
# Total rows: 203
#
# After enhanced cleaning:
# Removed 0 rows
# Remaining rows: 203
# Processed 203 rows -> P_C_NA csv final combined/A2018_Dirk Andres v European Commission___annotated_judgment.csv
# Processing R2017_European Commission v Frucona Košice a___annotated_judgment.csv...
# Before enhanced cleaning:
# Total rows: 181
#
# After enhanced cleaning:
# Removed 3 rows
# Remaining rows: 178
# Processed 178 rows -> P_C_NA csv final combined/R2017_European Commission v Frucona Košice a___annotated_judgment.csv
# Processing R2021_World Duty Free v. Commission___annotated_judgment.csv...
# Before enhanced cleaning:
# Total rows: 294
#
# After enhanced cleaning:
# Removed 3 rows
# Remaining rows: 291
# Processed 291 rows -> P_C_NA csv final combined/R2021_World Duty Free v. Commission___annotated_judgment.csv
# Processing L_A2013_Frucona Košice a.s. v European Commission (3)_annotated_judgment.csv...
# Before enhanced cleaning:
# Total rows: 189
#
# After enhanced cleaning:
# Removed 6 rows
# Remaining rows: 183
# Processed 183 rows -> P_C_NA csv final combined/L_A2013_Frucona Košice a.s. v European Commission (3)_annotated_judgment.csv
# Processing A2018_Commission v Spain___annotated_judgment.csv...
# Before enhanced cleaning:
# Total rows: 233
#
# After enhanced cleaning:
# Removed 3 rows
# Remaining rows: 230
# Processed 230 rows -> P_C_NA csv final combined/A2018_Commission v Spain___annotated_judgment.csv
# Processing A2012__BNP Paribas and Banca Nazionale del Lavoro SpA (BNL) v European Commission___annotated_judgment.csv...
# Before enhanced cleaning:
# Total rows: 289
#
# After enhanced cleaning:
# Removed 1 rows
# Remaining rows: 288
# Processed 288 rows -> P_C_NA csv final combined/A2012__BNP Paribas and Banca Nazionale del Lavoro SpA (BNL) v European Commission___annotated_judgment.csv
# Processing A2017__European Commission v Italian Republic_DT___annotated_judgment.csv...
# Before enhanced cleaning:
# Total rows: 124
#
# After enhanced cleaning:
# Removed 2 rows
# Remaining rows: 122
# Processed 122 rows -> P_C_NA csv final combined/A2017__European Commission v Italian Republic_DT___annotated_judgment.csv
# Processing L_A2008_Commission of the European Communities v Salzgitter AG (2)_annotated_judgment.csv...
# Before enhanced cleaning:
# Total rows: 177
#
# After enhanced cleaning:
# Removed 4 rows
# Remaining rows: 173
# Processed 173 rows -> P_C_NA csv final combined/L_A2008_Commission of the European Communities v Salzgitter AG (2)_annotated_judgment.csv
# Processing L_R2004_Daewoo Electronics Manufacturing España SA and Territorio Histórico de Álava - Diputación Foral de Álava v Commission of the European Communities_annotated_judgment.csv...
# Before enhanced cleaning:
# Total rows: 142
#
# After enhanced cleaning:
# Removed 14 rows
# Remaining rows: 128
# Processed 128 rows -> P_C_NA csv final combined/L_R2004_Daewoo Electronics Manufacturing España SA and Territorio Histórico de Álava - Diputación Foral de Álava v Commission of the European Communities_annotated_judgment.csv
# Processing A2009_Commission of the European Communities v Koninklijke FrieslandCampina NV_M___annotated_judgment.csv...
# Before enhanced cleaning:
# Total rows: 188
#
# After enhanced cleaning:
# Removed 2 rows
# Remaining rows: 186
# Processed 186 rows -> P_C_NA csv final combined/A2009_Commission of the European Communities v Koninklijke FrieslandCampina NV_M___annotated_judgment.csv
# Processing L_A2017_European Commission v TV2_Danmark A_S _annotated_judgment.csv...
# Before enhanced cleaning:
# Total rows: 122
#
# After enhanced cleaning:
# Removed 1 rows
# Remaining rows: 121
# Processed 121 rows -> P_C_NA csv final combined/L_A2017_European Commission v TV2_Danmark A_S _annotated_judgment.csv
# Processing R2021_FVE Holýšov I and Others v Commission___annotated_judgment.csv...
# Before enhanced cleaning:
# Total rows: 169
#
# After enhanced cleaning:
# Removed 1 rows
# Remaining rows: 168
# Processed 168 rows -> P_C_NA csv final combined/R2021_FVE Holýšov I and Others v Commission___annotated_judgment.csv
# Processing R2021_Prosegur Compañía de Seguridad SA, established in Madrid (Spain) v Commission___annotated_judgment.csv...
# Before enhanced cleaning:
# Total rows: 246
#
# After enhanced cleaning:
# Removed 4 rows
# Remaining rows: 242
# Processed 242 rows -> P_C_NA csv final combined/R2021_Prosegur Compañía de Seguridad SA, established in Madrid (Spain) v Commission___annotated_judgment.csv
# Processing A2011_European Commission (C-106_09 P) and Kingdom of Spain (C-107_09 P) v Government of Gibraltar and United Kingdom of Great Britain and Northern Ireland___annotated_judgment.csv...
# Before enhanced cleaning:
# Total rows: 1427
#
# After enhanced cleaning:
# Removed 1053 rows
# Remaining rows: 374
# Processed 374 rows -> P_C_NA csv final combined/A2011_European Commission (C-106_09 P) and Kingdom of Spain (C-107_09 P) v Government of Gibraltar and United Kingdom of Great Britain and Northern Ireland___annotated_judgment.csv
# Processing L_R1997_Tiercé Ladbroke SA v Commission of the European Communities_annotated_judgment.csv...
# Before enhanced cleaning:
# Total rows: 78
#
# After enhanced cleaning:
# Removed 1 rows
# Remaining rows: 77
# Processed 77 rows -> P_C_NA csv final combined/L_R1997_Tiercé Ladbroke SA v Commission of the European Communities_annotated_judgment.csv
# Processing R2013_Telefónica SA v European Commission___annotated_judgment.csv...
# Before enhanced cleaning:
# Total rows: 127
#
# After enhanced cleaning:
# Removed 0 rows
# Remaining rows: 127
# Processed 127 rows -> P_C_NA csv final combined/R2013_Telefónica SA v European Commission___annotated_judgment.csv
# Processing R2016_European Commission v Hansestadt Lübeck___annotated_judgment.csv...
# Before enhanced cleaning:
# Total rows: 144
#
# After enhanced cleaning:
# Removed 2 rows
# Remaining rows: 142
# Processed 142 rows -> P_C_NA csv final combined/R2016_European Commission v Hansestadt Lübeck___annotated_judgment.csv
# Processing R2004_Italian Republic v Commission of the European Communities___annotated_judgment.csv...
# Before enhanced cleaning:
# Total rows: 268
#
# After enhanced cleaning:
# Removed 2 rows
# Remaining rows: 266
# Processed 266 rows -> P_C_NA csv final combined/R2004_Italian Republic v Commission of the European Communities___annotated_judgment.csv
# Processing L_R2010_AceaElectrabel Produzione SpA v European Commission_annotated_judgment.csv...
# Before enhanced cleaning:
# Total rows: 204
#
# After enhanced cleaning:
# Removed 15 rows
# Remaining rows: 189
# Processed 189 rows -> P_C_NA csv final combined/L_R2010_AceaElectrabel Produzione SpA v European Commission_annotated_judgment.csv
# Processing L_A2016_European Commission v Aer Lingus Ltd and Ryanair Designated Activity Company (3)_annotated_judgment.csv...
# Before enhanced cleaning:
# Total rows: 238
#
# After enhanced cleaning:
# Removed 0 rows
# Remaining rows: 238
# Processed 238 rows -> P_C_NA csv final combined/L_A2016_European Commission v Aer Lingus Ltd and Ryanair Designated Activity Company (3)_annotated_judgment.csv
# Processing R2013_3F, formerly Specialarbejderforbundet i Danmark (SID) v European Commission___annotated_judgment.csv...
# Before enhanced cleaning:
# Total rows: 166
#
# After enhanced cleaning:
# Removed 1 rows
# Remaining rows: 165
# Processed 165 rows -> P_C_NA csv final combined/R2013_3F, formerly Specialarbejderforbundet i Danmark (SID) v European Commission___annotated_judgment.csv
# Processing R2016_Hellenic Republic v European Commission___annotated_judgment.csv...
# Before enhanced cleaning:
# Total rows: 156
#
# After enhanced cleaning:
# Removed 2 rows
# Remaining rows: 154
# Processed 154 rows -> P_C_NA csv final combined/R2016_Hellenic Republic v European Commission___annotated_judgment.csv
# Processing A2017_European Commission v Italian Republic_DT___annotated_judgment.csv...
# Before enhanced cleaning:
# Total rows: 124
#
# After enhanced cleaning:
# Removed 2 rows
# Remaining rows: 122
# Processed 122 rows -> P_C_NA csv final combined/A2017_European Commission v Italian Republic_DT___annotated_judgment.csv
# Processing A2013_European Commission v Ireland and Others___annotated_judgment.csv...
# Before enhanced cleaning:
# Total rows: 107
#
# After enhanced cleaning:
# Removed 2 rows
# Remaining rows: 105
# Processed 105 rows -> P_C_NA csv final combined/A2013_European Commission v Ireland and Others___annotated_judgment.csv
# Processing L_R2012_European Commission v Électricité de France (EDF)_annotated_judgment.csv...
# Before enhanced cleaning:
# Total rows: 239
#
# After enhanced cleaning:
# Removed 19 rows
# Remaining rows: 220
# Processed 220 rows -> P_C_NA csv final combined/L_R2012_European Commission v Électricité de France (EDF)_annotated_judgment.csv
# Processing L_A2009_3F v Commission of the European Communities (2)_annotated_judgment.csv...
# Before enhanced cleaning:
# Total rows: 209
#
# After enhanced cleaning:
# Removed 0 rows
# Remaining rows: 209
# Processed 209 rows -> P_C_NA csv final combined/L_A2009_3F v Commission of the European Communities (2)_annotated_judgment.csv
# Processing R2016_Netherlands Maritime Technology Association formerly Scheepsbouw Nederland v European Commission___annotated_judgment.csv...
# Before enhanced cleaning:
# Total rows: 198
#
# After enhanced cleaning:
# Removed 0 rows
# Remaining rows: 198
# Processed 198 rows -> P_C_NA csv final combined/R2016_Netherlands Maritime Technology Association formerly Scheepsbouw Nederland v European Commission___annotated_judgment.csv
# Processing R2017__Viasat Broadcasting UK Ltd v European Commission___annotated_judgment.csv...
# Before enhanced cleaning:
# Total rows: 125
#
# After enhanced cleaning:
# Removed 0 rows
# Remaining rows: 125
# Processed 125 rows -> P_C_NA csv final combined/R2017__Viasat Broadcasting UK Ltd v European Commission___annotated_judgment.csv

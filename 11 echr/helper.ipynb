# %%
import os
import pandas as pd

# Define the input and output directories
input_dir = 'sir p_c_na'
output_dir = 'arg_vs_non-arg'

# Create output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Check if input directory exists
if not os.path.exists(input_dir):
    print(f"Error: Input directory '{input_dir}' does not exist.")
    print("Please ensure the 'data/all' folder exists and contains CSV files.")
else:
    # List all CSV files in the input directory
    csv_files = [f for f in os.listdir(input_dir) if f.endswith('.csv')]
    
    if not csv_files:
        print("No CSV files found in the input directory.")
    else:
        print(f"Found {len(csv_files)} CSV files to process:")
        
        # Process each CSV file
        for file in csv_files:
            try:
                # Read the CSV file
                input_path = os.path.join(input_dir, file)
                df = pd.read_csv(input_path)
                
                # Check if required columns exist
                if 'text' not in df.columns or 'label' not in df.columns:
                    print(f"Warning: {file} doesn't have required 'text' and 'label' columns. Skipping.")
                    continue
                
                # Update labels: convert 'premise' and 'conclusion' to 'argumentative'
                df['label'] = df['label'].replace({
                    'premise': 'argumentative', 
                    'conclusion': 'argumentative'
                })
                
                # Save the updated CSV to the output directory
                output_path = os.path.join(output_dir, file)
                df.to_csv(output_path, index=False)
                
                print(f"✓ Processed {file} - Labels updated and saved to {output_dir}")
                
                # Show label distribution for this file
                label_counts = df['label'].value_counts()
                print(f"  Label distribution: {dict(label_counts)}")
                
            except Exception as e:
                print(f"Error processing {file}: {str(e)}")
        
        print(f"\nAll files processed successfully! Updated CSVs saved in '{output_dir}' folder.")
# Out:
# Found 42 CSV files to process:
# ✓ Processed 34.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 279, 'argumentative': 153}
# ✓ Processed 01.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 189, 'argumentative': 66}
# ✓ Processed 05.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 80, 'argumentative': 40}
# ✓ Processed 22.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 332, 'argumentative': 197}
# ✓ Processed 09.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 307, 'argumentative': 32}
# ✓ Processed 25.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 166, 'argumentative': 58}
# ✓ Processed 31.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 39, 'argumentative': 22}
# ✓ Processed 33.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 46, 'argumentative': 34}
# ✓ Processed 21.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 167, 'argumentative': 54}
# ✓ Processed 14.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 264, 'argumentative': 79}
# ✓ Processed 40.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 42, 'argumentative': 13}
# ✓ Processed 03.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 227, 'argumentative': 22}
# ✓ Processed 42.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 55, 'argumentative': 21}
# ✓ Processed 16.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 200, 'argumentative': 41}
# ✓ Processed 12.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 226, 'argumentative': 49}
# ✓ Processed 28.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 280, 'argumentative': 111}
# ✓ Processed 18.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 352, 'argumentative': 67}
# ✓ Processed 19.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 262, 'argumentative': 138}
# ✓ Processed 41.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 35, 'argumentative': 12}
# ✓ Processed 08.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 306, 'argumentative': 135}
# ✓ Processed 20.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 156, 'argumentative': 73}
# ✓ Processed 27.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 338, 'argumentative': 116}
# ✓ Processed 29.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 269, 'argumentative': 106}
# ✓ Processed 17.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 535, 'argumentative': 134}
# ✓ Processed 15.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 153, 'argumentative': 71}
# ✓ Processed 35.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 53, 'argumentative': 18}
# ✓ Processed 23.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 148, 'argumentative': 50}
# ✓ Processed 30.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 212, 'argumentative': 27}
# ✓ Processed 26.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 175, 'argumentative': 61}
# ✓ Processed 04.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 76, 'argumentative': 26}
# ✓ Processed 11.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 316, 'argumentative': 141}
# ✓ Processed 13.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 86, 'argumentative': 24}
# ✓ Processed 38.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 86, 'argumentative': 43}
# ✓ Processed 39.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 114, 'argumentative': 23}
# ✓ Processed 07.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 289, 'argumentative': 80}
# ✓ Processed 02.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 98, 'argumentative': 25}
# ✓ Processed 32.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 92, 'argumentative': 26}
# ✓ Processed 24.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 111, 'argumentative': 64}
# ✓ Processed 10.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 164, 'argumentative': 43}
# ✓ Processed 06.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 98, 'argumentative': 31}
# ✓ Processed 00.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'argumentative': 75, 'non-argumentative': 68}
# ✓ Processed 37.csv - Labels updated and saved to arg_vs_non-arg
#   Label distribution: {'non-argumentative': 271, 'argumentative': 93}
#
# All files processed successfully! Updated CSVs saved in 'arg_vs_non-arg' folder.

# %%
import os
import pandas as pd

# Define the input and output directories
input_dir = 'sir p_c_na'  # Using original data to get premise/conclusion labels
output_dir = 'prem_vs_conc'

# Create output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Check if input directory exists
if not os.path.exists(input_dir):
    print(f"Error: Input directory '{input_dir}' does not exist.")
    print("Please ensure the 'data/all' folder exists and contains CSV files.")
else:
    # List all CSV files in the input directory
    csv_files = [f for f in os.listdir(input_dir) if f.endswith('.csv')]
    
    if not csv_files:
        print("No CSV files found in the input directory.")
    else:
        print(f"Found {len(csv_files)} CSV files to process:")
        
        # Process each CSV file
        for file in csv_files:
            try:
                # Read the CSV file
                input_path = os.path.join(input_dir, file)
                df = pd.read_csv(input_path)
                
                # Check if required columns exist
                if 'text' not in df.columns or 'label' not in df.columns:
                    print(f"Warning: {file} doesn't have required 'text' and 'label' columns. Skipping.")
                    continue
                
                # Filter to keep only 'premise' and 'conclusion' labels
                filtered_df = df[df['label'].isin(['premise', 'conclusion'])].copy()
                
                # Check if there are any rows left after filtering
                if filtered_df.empty:
                    print(f"Warning: {file} has no 'premise' or 'conclusion' labels. Skipping.")
                    continue
                
                # Save the filtered CSV to the output directory
                output_path = os.path.join(output_dir, file)
                filtered_df.to_csv(output_path, index=False)
                
                print(f"✓ Processed {file}")
                print(f"  Original rows: {len(df)}")
                print(f"  Filtered rows: {len(filtered_df)}")
                
                # Show label distribution for this file
                label_counts = filtered_df['label'].value_counts()
                print(f"  Label distribution: {dict(label_counts)}")
                print()
                
            except Exception as e:
                print(f"Error processing {file}: {str(e)}")
        
        print(f"All files processed successfully! Filtered CSVs saved in '{output_dir}' folder.")
        print("Only 'premise' and 'conclusion' labels are retained.")
# Out:
# Found 42 CSV files to process:
# ✓ Processed 34.csv
#   Original rows: 432
#   Filtered rows: 153
#   Label distribution: {'premise': 105, 'conclusion': 48}
#
# ✓ Processed 01.csv
#   Original rows: 255
#   Filtered rows: 66
#   Label distribution: {'premise': 46, 'conclusion': 20}
#
# ✓ Processed 05.csv
#   Original rows: 120
#   Filtered rows: 40
#   Label distribution: {'premise': 25, 'conclusion': 15}
#
# ✓ Processed 22.csv
#   Original rows: 529
#   Filtered rows: 197
#   Label distribution: {'premise': 147, 'conclusion': 50}
#
# ✓ Processed 09.csv
#   Original rows: 339
#   Filtered rows: 32
#   Label distribution: {'premise': 21, 'conclusion': 11}
#
# ✓ Processed 25.csv
#   Original rows: 224
#   Filtered rows: 58
#   Label distribution: {'premise': 43, 'conclusion': 15}
#
# ✓ Processed 31.csv
#   Original rows: 61
#   Filtered rows: 22
#   Label distribution: {'premise': 15, 'conclusion': 7}
#
# ✓ Processed 33.csv
#   Original rows: 80
#   Filtered rows: 34
#   Label distribution: {'premise': 22, 'conclusion': 12}
#
# ✓ Processed 21.csv
#   Original rows: 221
#   Filtered rows: 54
#   Label distribution: {'premise': 41, 'conclusion': 13}
#
# ✓ Processed 14.csv
#   Original rows: 343
#   Filtered rows: 79
#   Label distribution: {'premise': 60, 'conclusion': 19}
#
# ✓ Processed 40.csv
#   Original rows: 55
#   Filtered rows: 13
#   Label distribution: {'premise': 8, 'conclusion': 5}
#
# ✓ Processed 03.csv
#   Original rows: 249
#   Filtered rows: 22
#   Label distribution: {'premise': 15, 'conclusion': 7}
#
# ✓ Processed 42.csv
#   Original rows: 76
#   Filtered rows: 21
#   Label distribution: {'premise': 14, 'conclusion': 7}
#
# ✓ Processed 16.csv
#   Original rows: 241
#   Filtered rows: 41
#   Label distribution: {'premise': 32, 'conclusion': 9}
#
# ✓ Processed 12.csv
#   Original rows: 275
#   Filtered rows: 49
#   Label distribution: {'premise': 33, 'conclusion': 16}
#
# ✓ Processed 28.csv
#   Original rows: 391
#   Filtered rows: 111
#   Label distribution: {'premise': 84, 'conclusion': 27}
#
# ✓ Processed 18.csv
#   Original rows: 419
#   Filtered rows: 67
#   Label distribution: {'premise': 54, 'conclusion': 13}
#
# ✓ Processed 19.csv
#   Original rows: 400
#   Filtered rows: 138
#   Label distribution: {'premise': 107, 'conclusion': 31}
#
# ✓ Processed 41.csv
#   Original rows: 47
#   Filtered rows: 12
#   Label distribution: {'premise': 8, 'conclusion': 4}
#
# ✓ Processed 08.csv
#   Original rows: 441
#   Filtered rows: 135
#   Label distribution: {'premise': 88, 'conclusion': 47}
#
# ✓ Processed 20.csv
#   Original rows: 229
#   Filtered rows: 73
#   Label distribution: {'premise': 53, 'conclusion': 20}
#
# ✓ Processed 27.csv
#   Original rows: 454
#   Filtered rows: 116
#   Label distribution: {'premise': 97, 'conclusion': 19}
#
# ✓ Processed 29.csv
#   Original rows: 375
#   Filtered rows: 106
#   Label distribution: {'premise': 79, 'conclusion': 27}
#
# ✓ Processed 17.csv
#   Original rows: 669
#   Filtered rows: 134
#   Label distribution: {'premise': 99, 'conclusion': 35}
#
# ✓ Processed 15.csv
#   Original rows: 224
#   Filtered rows: 71
#   Label distribution: {'premise': 54, 'conclusion': 17}
#
# ✓ Processed 35.csv
#   Original rows: 71
#   Filtered rows: 18
#   Label distribution: {'premise': 11, 'conclusion': 7}
#
# ✓ Processed 23.csv
#   Original rows: 198
#   Filtered rows: 50
#   Label distribution: {'premise': 38, 'conclusion': 12}
#
# ✓ Processed 30.csv
#   Original rows: 239
#   Filtered rows: 27
#   Label distribution: {'premise': 23, 'conclusion': 4}
#
# ✓ Processed 26.csv
#   Original rows: 236
#   Filtered rows: 61
#   Label distribution: {'premise': 45, 'conclusion': 16}
#
# ✓ Processed 04.csv
#   Original rows: 102
#   Filtered rows: 26
#   Label distribution: {'premise': 14, 'conclusion': 12}
#
# ✓ Processed 11.csv
#   Original rows: 457
#   Filtered rows: 141
#   Label distribution: {'premise': 105, 'conclusion': 36}
#
# ✓ Processed 13.csv
#   Original rows: 110
#   Filtered rows: 24
#   Label distribution: {'premise': 19, 'conclusion': 5}
#
# ✓ Processed 38.csv
#   Original rows: 129
#   Filtered rows: 43
#   Label distribution: {'premise': 32, 'conclusion': 11}
#
# ✓ Processed 39.csv
#   Original rows: 137
#   Filtered rows: 23
#   Label distribution: {'premise': 15, 'conclusion': 8}
#
# ✓ Processed 07.csv
#   Original rows: 369
#   Filtered rows: 80
#   Label distribution: {'premise': 48, 'conclusion': 32}
#
# ✓ Processed 02.csv
#   Original rows: 123
#   Filtered rows: 25
#   Label distribution: {'premise': 17, 'conclusion': 8}
#
# ✓ Processed 32.csv
#   Original rows: 118
#   Filtered rows: 26
#   Label distribution: {'premise': 17, 'conclusion': 9}
#
# ✓ Processed 24.csv
#   Original rows: 175
#   Filtered rows: 64
#   Label distribution: {'premise': 49, 'conclusion': 15}
#
# ✓ Processed 10.csv
#   Original rows: 207
#   Filtered rows: 43
#   Label distribution: {'premise': 32, 'conclusion': 11}
#
# ✓ Processed 06.csv
#   Original rows: 129
#   Filtered rows: 31
#   Label distribution: {'premise': 18, 'conclusion': 13}
#
# ✓ Processed 00.csv
#   Original rows: 143
#   Filtered rows: 75
#   Label distribution: {'premise': 51, 'conclusion': 24}
#
# ✓ Processed 37.csv
#   Original rows: 364
#   Filtered rows: 93
#   Label distribution: {'premise': 67, 'conclusion': 26}
#
# All files processed successfully! Filtered CSVs saved in 'prem_vs_conc' folder.
# Only 'premise' and 'conclusion' labels are retained.

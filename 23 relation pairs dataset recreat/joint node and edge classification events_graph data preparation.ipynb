# %% [markdown]
# # graph data preparation

# %%
import os
from pathlib import Path
import pandas as pd
from transformers import AutoTokenizer, AutoModel
import torch
from torch_geometric.data import Data
from tqdm import tqdm

# %%
CSV_PATH = Path("8 updated_events PCNA_SANR_final.csv")
OUTPUT_DIR = Path("BERT_processed_updated_PCNA_graph_data_for_joint_prediction_csv")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# %%
tokenizer = AutoTokenizer.from_pretrained('suyamoonpathak/bert-pcna-updated-events-finetuned')
model = AutoModel.from_pretrained('suyamoonpathak/bert-pcna-updated-events-finetuned')
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %%
# Edge type mapping from CSV relations to integers compatible with previous code convention
relation_to_edge_type = {
    "support": 0,
    "attack": 1,
    "no-relation": 2
}

# Node label mapping for node classification
node_type_to_label = {
    "prem": 0,
    "conc": 1,
    "na": 2
}

# Priority order for node type when a node appears as both source and target with different types
node_type_priority = {
    "conc": 3,
    "prem": 2,
    "na": 1,
}

# %%
def generate_embeddings(texts, batch_size=4):
    embeddings = []
    for i in tqdm(range(0, len(texts), batch_size), desc="Generating embeddings"):
        batch = texts[i:i+batch_size]
        inputs = tokenizer(batch,
                           padding=True,
                           truncation=True,
                           max_length=512,
                           return_tensors="pt").to(device)
        with torch.no_grad():
            outputs = model(**inputs)
        embeddings.append(outputs.last_hidden_state[:, 0, :].cpu())
    return torch.cat(embeddings, dim=0)

def generate_raw_embeddings_from_word_embeddings(texts, batch_size=8):
    embeddings = []
    
    for i in range(0, len(texts), batch_size):
        batch = texts[i:i+batch_size]
        inputs = tokenizer(
            batch, 
            padding=True, 
            truncation=True, 
            max_length=512, 
            return_tensors="pt"
        ).to(device)
        
        # Extract token IDs from the tokenizer output
        input_ids = inputs['input_ids']
        
        with torch.no_grad():
            # Get the embeddings directly from the embedding layer
            word_embeddings = model.embeddings.word_embeddings(input_ids)
            
            cls_embeddings = word_embeddings[:, 0, :]  
            
            embeddings.append(cls_embeddings.cpu())
    
    return torch.cat(embeddings, dim=0)


def generate_gaussian_embeddings(texts, batch_size=4):
    hidden_size = model.config.hidden_size
    # hidden_size should be set to match model.config.hidden_size
    if hidden_size is None:
        raise ValueError("hidden_size must be specified to match the model's output dimensionality.")
    
    embeddings = []
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    
    for i in tqdm(range(0, len(texts), batch_size)):
        batch_len = len(texts[i:i+batch_size])
        # Generate gaussian noise with shape [batch_len, hidden_size]
        noise = torch.randn(batch_len, hidden_size).to(device)
        embeddings.append(noise.cpu())
    
    return torch.cat(embeddings, dim=0)

# %%
def determine_node_types(key_type_map):
    """
    Given mapping from node keys to set of types, determine by priority.
    """
    node_types = {}
    for key, types in key_type_map.items():
        best_type = None
        best_priority = 0
        for t in types:
            prio = node_type_priority.get(t, 0)
            if prio > best_priority:
                best_priority = prio
                best_type = t
        node_types[key] = best_type
    return node_types

# %%
df = pd.read_csv(CSV_PATH)
file_names = df['file_name'].unique()
assert len(file_names) == 40, f"Expected 40 files, found {len(file_names)}"

# %%
all_data = []
for file_name in tqdm(file_names, desc="Processing cases"):
    sub_df = df[df['file_name'] == file_name]
    node_key_texts = {}
    key_type_map = {}

    # First pass: collect all unique node keys and texts, types
    for _, row in sub_df.iterrows():
        for role in ["source", "target"]:
            node_ID = row[f"{role}_ID"]
            node_text = str(row[f"{role}_text"]) if pd.notnull(row[f"{role}_text"]) else ""
            node_type = row[f"{role}_type"].strip().lower()
            key = (node_ID, node_text, file_name) if node_text else (node_ID, file_name)
            node_key_texts[key] = node_text
            key_type_map.setdefault(key, set()).add(node_type)

    # Assign node type per priority
    node_types = determine_node_types(key_type_map)

    # Build node index
    node_keys = list(node_key_texts.keys())
    key_to_idx = {key: idx for idx, key in enumerate(node_keys)}
    texts_for_embedding = [node_key_texts[key] if node_key_texts[key]!="" else "empty" for key in node_keys]
    embeddings = generate_embeddings(texts_for_embedding)

    # 6. Create one-hot encoded node type features (3 classes)
    node_features_type = torch.zeros((len(node_keys), 3))
    node_labels = []
    for i, key in enumerate(node_keys):
        ntype = node_types[key]
        label = node_type_to_label.get(ntype, 2)  # Default non-argumentative if missing
        node_labels.append(label)
        if ntype == "prem":
            node_features_type[i, 0] = 1
        elif ntype == "conc":
            node_features_type[i, 1] = 1
        elif ntype == "na":
            node_features_type[i, 2] = 1

    node_labels = torch.tensor(node_labels, dtype=torch.long)
    node_features = torch.cat([embeddings, node_features_type], dim=1)

    # 7. Build edges - edge indices and edge types
    edge_indices = []
    edge_types = []
    for _, row in sub_df.iterrows():
        src_ID = row['source_ID']
        src_text = str(row['source_text']) if pd.notnull(row['source_text']) else ""
        tgt_ID = row['target_ID']
        tgt_text = str(row['target_text']) if pd.notnull(row['target_text']) else ""
        rel = row['relation'].strip().lower()

        src_key = (src_ID, src_text, file_name) if src_text else (src_ID, file_name)
        tgt_key = (tgt_ID, tgt_text, file_name) if tgt_text else (tgt_ID, file_name)
        if src_key in key_to_idx and tgt_key in key_to_idx:
            edge_indices.append([key_to_idx[src_key], key_to_idx[tgt_key]])
            edge_types.append(relation_to_edge_type[rel])
        else:
            print(f"Warning: Missing node index for edge {src_key} -> {tgt_key} in file {file_name}")

    edge_index = torch.tensor(edge_indices, dtype=torch.long).t().contiguous()
    edge_type = torch.tensor(edge_types, dtype=torch.long)

    data = Data(
        x=node_features,
        edge_index=edge_index,
        edge_type=edge_type,
        y=node_labels,
        xml_file=file_name
    )
    output_path = OUTPUT_DIR / f"{file_name}.pt"
    torch.save(data, output_path)
    all_data.append(data)
# Out:
# Generating embeddings: 100%|██████████| 46/46 [00:00<00:00, 83.58it/s]
# Generating embeddings: 100%|██████████| 46/46 [00:00<00:00, 95.16it/s]
# Generating embeddings: 100%|██████████| 36/36 [00:00<00:00, 94.10it/s]
# Generating embeddings: 100%|██████████| 40/40 [00:00<00:00, 99.19it/s]
# Generating embeddings: 100%|██████████| 29/29 [00:00<00:00, 95.37it/s]
# Generating embeddings: 100%|██████████| 46/46 [00:00<00:00, 102.22it/s]
# Generating embeddings: 100%|██████████| 44/44 [00:00<00:00, 98.23it/s]
# Generating embeddings: 100%|██████████| 34/34 [00:00<00:00, 95.70it/s]
# Generating embeddings: 100%|██████████| 32/32 [00:00<00:00, 91.68it/s]
# Generating embeddings: 100%|██████████| 29/29 [00:00<00:00, 87.74it/s]
# Generating embeddings: 100%|██████████| 31/31 [00:00<00:00, 94.86it/s]
# Generating embeddings: 100%|██████████| 40/40 [00:00<00:00, 94.44it/s]
# Generating embeddings: 100%|██████████| 32/32 [00:00<00:00, 96.97it/s]
# Generating embeddings: 100%|██████████| 38/38 [00:00<00:00, 98.33it/s]
# Generating embeddings: 100%|██████████| 55/55 [00:00<00:00, 101.12it/s]
# Generating embeddings: 100%|██████████| 25/25 [00:00<00:00, 92.56it/s]
# Generating embeddings: 100%|██████████| 41/41 [00:00<00:00, 99.67it/s]
# Generating embeddings: 100%|██████████| 39/39 [00:00<00:00, 96.03it/s]
# Generating embeddings: 100%|██████████| 30/30 [00:00<00:00, 105.05it/s]
# Generating embeddings: 100%|██████████| 30/30 [00:00<00:00, 86.49it/s]
# Generating embeddings: 100%|██████████| 20/20 [00:00<00:00, 82.73it/s]
# Generating embeddings: 100%|██████████| 40/40 [00:00<00:00, 100.03it/s]
# Generating embeddings: 100%|██████████| 29/29 [00:00<00:00, 97.44it/s]
# Generating embeddings: 100%|██████████| 46/46 [00:00<00:00, 100.54it/s]
# Generating embeddings: 100%|██████████| 34/34 [00:00<00:00, 102.00it/s]
# Generating embeddings: 100%|██████████| 32/32 [00:00<00:00, 106.93it/s]
# Generating embeddings: 100%|██████████| 55/55 [00:00<00:00, 109.02it/s]
# Generating embeddings: 100%|██████████| 37/37 [00:00<00:00, 100.93it/s]
# Generating embeddings: 100%|██████████| 33/33 [00:00<00:00, 106.68it/s]
# Generating embeddings: 100%|██████████| 38/38 [00:00<00:00, 102.22it/s]
# Generating embeddings: 100%|██████████| 46/46 [00:00<00:00, 96.56it/s]
# Generating embeddings: 100%|██████████| 31/31 [00:00<00:00, 102.95it/s]
# Generating embeddings: 100%|██████████| 51/51 [00:00<00:00, 108.13it/s]
# Generating embeddings: 100%|██████████| 38/38 [00:00<00:00, 105.67it/s]
# Generating embeddings: 100%|██████████| 36/36 [00:00<00:00, 101.35it/s]
# Generating embeddings: 100%|██████████| 53/53 [00:00<00:00, 109.66it/s]
# Generating embeddings: 100%|██████████| 27/27 [00:00<00:00, 84.88it/s]
# Generating embeddings: 100%|██████████| 34/34 [00:00<00:00, 132.68it/s]
# Generating embeddings: 100%|██████████| 25/25 [00:00<00:00, 105.16it/s]
# Generating embeddings: 100%|██████████| 43/43 [00:00<00:00, 127.90it/s]
# Processing cases: 100%|██████████| 40/40 [00:19<00:00,  2.04it/s]

# %%
print(f"Processed and saved {len(all_data)} files.")

assert len(all_data) == 40, f"Warning: processed file count mismatch, expected 40 but got {len(all_data)}"
# Out:
# Processed and saved 40 files.

# %%
import torch
from pathlib import Path

def get_dataset_stats(output_dir="LegalBERT_raw_graph_data_for_joint_prediction_csv"):
    pt_files = list(Path(output_dir).glob("*.pt"))
    if not pt_files:
        return "No processed files found. Run XML processing first."

    total_stats = {
        'total_nodes': 0,
        'total_support': 0,
        'total_attack': 0,
        'total_no_relation': 0,  
        'files': []
    }


    for pt_file in pt_files:
        try:
            data = torch.load(pt_file, weights_only=False)
            support = (data.edge_type == 0).sum().item()
            attack = (data.edge_type == 1).sum().item()
            no_relation = (data.edge_type == 2).sum().item()  

            
            file_stats = {
                'filename': pt_file.name,
                'nodes': data.x.shape[0],
                'support': support,
                'attack': attack,
                'no_relation': no_relation
            }
            
            total_stats['total_nodes'] += file_stats['nodes']
            total_stats['total_support'] += support
            total_stats['total_attack'] += attack
            total_stats['total_no_relation'] += no_relation
            total_stats['files'].append(file_stats)
            
            
        except Exception as e:
            print(f"Error loading {pt_file.name}: {str(e)}")
    
    return total_stats

stats = get_dataset_stats()

print(f"""
## Dataset Summary
- **Total Documents**: {len(stats['files'])}
- **Total Arguments**: {stats['total_nodes']}
- **Support Relationships**: {stats['total_support']}
- **Attack Relationships**: {stats['total_attack']}
- **No-Relation Pairs**: {stats['total_no_relation']}
- **Ratio (Support:Attack:NoRel)**: {stats['total_support']}:{stats['total_attack']}:{stats['total_no_relation']}
""")

for file in stats['files']:
    print(f"""
**{file['filename']}**
- Nodes: {file['nodes']}
- Support: {file['support']}
- Attack: {file['attack']}
- No-Relation: {file['no_relation']}""")
# Out:
# ## Dataset Summary
# - **Total Documents**: 40
# - **Total Arguments**: 5896
# - **Support Relationships**: 2272
# - **Attack Relationships**: 145
# - **No-Relation Pairs**: 5008
# - **Ratio (Support:Attack:NoRel)**: 2272:145:5008
#
#
# **R2021_World Duty Free v. Commission.xml.pt**
# - Nodes: 216
# - Support: 116
# - Attack: 22
# - No-Relation: 125
#
# **A2017_Ellinikos Chrysos AE Metalleion kai Viomichanias Chrysou v European Commission.xml.pt**
# - Nodes: 101
# - Support: 24
# - Attack: 1
# - No-Relation: 125
#
# **A2010_NDSHT Nya Destination Stockholm Hotell & Teaterpaket AB v European Commission.xml.pt**
# - Nodes: 127
# - Support: 39
# - Attack: 1
# - No-Relation: 125
#
# **A2016_European_Commission_v_World_Duty_Free.xml.pt**
# - Nodes: 153
# - Support: 73
# - Attack: 1
# - No-Relation: 125
#
# **R2011_European Commission v Kronoply GmbH & Co.xml.pt**
# - Nodes: 118
# - Support: 48
# - Attack: 0
# - No-Relation: 125
#
# **A2016_European Commission v Aer Lingus Ltd and Ryanair Designated Activity Company.xml.pt**
# - Nodes: 179
# - Support: 61
# - Attack: 2
# - No-Relation: 126
#
# **R2010_AceaElectrabel Produzione SpA v European Commission.xml.pt**
# - Nodes: 151
# - Support: 65
# - Attack: 0
# - No-Relation: 125
#
# **R2016_Orange v European Commission.xml.pt**
# - Nodes: 124
# - Support: 69
# - Attack: 9
# - No-Relation: 125
#
# **R2016_European Commission v Hansestadt Lübeck.xml.pt**
# - Nodes: 124
# - Support: 65
# - Attack: 0
# - No-Relation: 125
#
# **A2012_BNP Paribas and Banca Nazionale del Lavoro SpA (BNL) v European Commission.xml.pt**
# - Nodes: 187
# - Support: 28
# - Attack: 4
# - No-Relation: 125
#
# **R2004_Italian Republic v Commission of the European Communities.xml.pt**
# - Nodes: 183
# - Support: 67
# - Attack: 0
# - No-Relation: 125
#
# **R2021_Prosegur Compañía de Seguridad SA, established in Madrid (Spain) v Commission.xml.pt**
# - Nodes: 206
# - Support: 116
# - Attack: 22
# - No-Relation: 126
#
# **R2016_Netherlands Maritime Technology Association formerly Scheepsbouw Nederland v European Commission.xml.pt**
# - Nodes: 154
# - Support: 58
# - Attack: 10
# - No-Relation: 125
#
# **R2015_European Commission v MOL Magyar Olaj- és Gázipari Nyrt.xml.pt**
# - Nodes: 136
# - Support: 40
# - Attack: 0
# - No-Relation: 125
#
# **R2021_FVE Holýšov I and Others v Commission.xml.pt**
# - Nodes: 139
# - Support: 34
# - Attack: 8
# - No-Relation: 126
#
# **A2009_3F v Commission of the European Communities.xml.pt**
# - Nodes: 158
# - Support: 59
# - Attack: 4
# - No-Relation: 125
#
# **R2006_European Commission v Italian Republic.xml.pt**
# - Nodes: 116
# - Support: 38
# - Attack: 1
# - No-Relation: 125
#
# **A2009_Commission of the European Communities v Koninklijke FrieslandCampina NV_M.xml.pt**
# - Nodes: 146
# - Support: 48
# - Attack: 0
# - No-Relation: 125
#
# **A2017_European Commission v Italian Republic_DT.xml.pt**
# - Nodes: 114
# - Support: 59
# - Attack: 1
# - No-Relation: 125
#
# **R2002_associação dos refinadores de açúcar portugueses.xml.pt**
# - Nodes: 223
# - Support: 95
# - Attack: 2
# - No-Relation: 127
#
# **A2018_Commission v Spain.xml.pt**
# - Nodes: 181
# - Support: 75
# - Attack: 5
# - No-Relation: 125
#
# **A2018_Scuola Elementare Maria Montessori Srl v European Commission.xml.pt**
# - Nodes: 170
# - Support: 107
# - Attack: 3
# - No-Relation: 125
#
# **R2017_European Commission v Frucona Košice a.xml.pt**
# - Nodes: 140
# - Support: 56
# - Attack: 0
# - No-Relation: 125
#
# **R2000_French Republic v Ladbroke Racing Ltd and Commission of the European Communitie.xml.pt**
# - Nodes: 143
# - Support: 47
# - Attack: 16
# - No-Relation: 125
#
# **R2017_Viasat Broadcasting UK Ltd v European Commission.xml.pt**
# - Nodes: 118
# - Support: 42
# - Attack: 3
# - No-Relation: 125
#
# **A2017_European Commission v TV2_Danmark A_S.xml.pt**
# - Nodes: 109
# - Support: 30
# - Attack: 1
# - No-Relation: 125
#
# **R2013_Telefónica SA v European Commission.xml.pt**
# - Nodes: 109
# - Support: 33
# - Attack: 1
# - No-Relation: 125
# - No-Relation: 125
#
# **R2016_DTS Distribuidora de Televisión Digital.xml.pt**
# - Nodes: 183
# - Support: 84
# - Attack: 6
# - No-Relation: 126
#
# **R2013_3F, formerly Specialarbejderforbundet i Danmark (SID) v European Commission.xml.pt**
# - Nodes: 142
# - Support: 44
# - Attack: 2
# - No-Relation: 125
# - No-Relation: 125
#
# **A2018_Dirk Andres v European Commission.xml.pt**
# - Nodes: 158
# - Support: 76
# - Attack: 5
# - No-Relation: 125
#
# **A2008_Commission of the European Communities v Salzgitter AG.xml.pt**
# - Nodes: 150
# - Support: 48
# - Attack: 2
# - No-Relation: 125
#
# **R2016_Hellenic Republic v European Commission.xml.pt**
# - Nodes: 137
# - Support: 90
# - Attack: 0
# - No-Relation: 125
# - No-Relation: 125
#
# **R2004_Ramondín SA and Ramondín Cápsulas SA (C-186_02 P) and Territorio Histórico de Álava - Diputación Foral de Álava (C-188_02 P) v Commission of the European Communities.xml.pt**
# - Nodes: 119
# - Support: 30
# - Attack: 1
# - No-Relation: 125
#
# **A2013_Frucona Košice a.s. v European Commission.xml.pt**
# - Nodes: 155
# - Support: 43
# - Attack: 1
# - No-Relation: 125
# - No-Relation: 125
#
# **R1997_Tiercé Ladbroke SA v Commission of the European Communities.xml.pt**
# - Nodes: 78
# - Support: 23
# - Attack: 4
# - No-Relation: 125
#
# **R2011_France Télécom SA v European Commission.xml.pt**
# - Nodes: 182
# - Support: 77
# - Attack: 0
# - No-Relation: 125
#
# **R2012_European Commission v Électricité de France (EDF).xml.pt**
# - Nodes: 149
# - Support: 52
# - Attack: 5
# - No-Relation: 125
#
# **R2004_Daewoo Electronics Manufacturing España SA and Territorio Histórico de Álava - Diputación Foral de Álava v Commission of the European Communities.xml.pt**
# - Nodes: 119
# - Support: 20
# - Attack: 0
# - No-Relation: 125
#
# **A2011_European Commission (C-106_09 P) and Kingdom of Spain (C-107_09 P) v Government of Gibraltar and United Kingdom of Great Britain and Northern Ireland.xml.pt**
# - Nodes: 198
# - Support: 46
# - Attack: 2
# - No-Relation: 125
#
# **A2013_European Commission v Ireland and Others.xml.pt**
# - Nodes: 101
# - Support: 47
# - Attack: 0
# - No-Relation: 127

# %%
import pandas as pd

# Load the filtered CSV file
df = pd.read_csv('4 PCNA_SANR_final.csv')
df = pd.read_csv('4 PCNA_SANR_final.csv')

# Count occurrences of each relation type in the 'relation' column
relation_counts = df['relation'].value_counts()

# Extract counts for 'support', 'attack', and 'no-relation'
support_count = relation_counts.get('support', 0)
attack_count = relation_counts.get('attack', 0)
no_relation_count = relation_counts.get('no-relation', 0)

# Print the counts
print(f"Support count: {support_count}")
print(f"Attack count: {attack_count}")
print(f"No-relation count: {no_relation_count}")
# Out:
# Support count: 2272
# Attack count: 145
# No-relation count: 5008
